# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Auto_price.csv")

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
#projecting one column
df['fuel-system'].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
df['fuel-system'].head()
# Out:
# 0    mpfi
# 1    mpfi
# 2    mpfi
# 3    mpfi
# 4    mpfi
# Name: fuel-system, dtype: object

# %%
df['engine-size'].max()
# Out:
# 326

# %%
df['engine-size'].mean()
# Out:
# 126.90731707317073

# %%
df['engine-size'].mean()
# Out:
# 126.90731707317073

# %%
df.loc[0:15,'make']
# Out:
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
# 5            audi
# 6            audi
# 7            audi
# 8            audi
# 9            audi
# 10            bmw
# 11            bmw
# 12            bmw
# 13            bmw
# 14            bmw
# 15            bmw
# Name: make, dtype: object

# %%
df.loc[0:15,'symboling':'length']
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
df.iloc[0:15, 0:4]
# Out:
#     symboling normalized-losses         make fuel-type
# 0           3                 ?  alfa-romero       gas
# 1           3                 ?  alfa-romero       gas
# 2           1                 ?  alfa-romero       gas
# 3           2               164         audi       gas
# 4           2               164         audi       gas
# 5           2                 ?         audi       gas
# 6           1               158         audi       gas
# 7           1                 ?         audi       gas
# 8           1               158         audi       gas
# 9           0                 ?         audi       gas
# 10          2               192          bmw       gas
# 11          0               192          bmw       gas
# 12          0               188          bmw       gas
# 13          0               188          bmw       gas
# 14          1                 ?          bmw       gas

# %%
df['symboling'].max()
# Out:
# 3

# %%
df['symboling'] == df['symboling'].max()
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: symboling, Length: 205, dtype: bool

# %%
df[df['engine-size'] == df['engine-size'].max()]
# Out:
#     symboling normalized-losses    make fuel-type aspiration num-of-doors  \
# 49          0                 ?  jaguar       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 49      sedan          rwd           front       102.0  ...          326
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# 49         mpfi  3.54    2.76              11.5        262      5000       13
#
#    highway-mpg  price
# 49          17  36000
#
# [1 rows x 26 columns]

# %%
#Indexing and row selection
df[df['engine-size'] == df['engine-size'].max()]['symboling']
# Out:
# 49    0
# Name: symboling, dtype: int64

# %%
df.sort_values(by='symboling', ascending=True)
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 198         -2               103          volvo       gas      turbo
# 196         -2               103          volvo       gas        std
# 194         -2               103          volvo       gas        std
# 204         -1                95          volvo       gas      turbo
# 67          -1                93  mercedes-benz    diesel      turbo
# ..         ...               ...            ...       ...        ...
# 132          3               150           saab       gas        std
# 134          3               150           saab       gas        std
# 136          3               150           saab       gas      turbo
# 57           3               150          mazda       gas        std
# 0            3                 ?    alfa-romero       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
#sorting
df.sort_values(by='engine-size', ascending=True).head()
# Out:
#     symboling normalized-losses       make fuel-type aspiration num-of-doors  \
# 18          2               121  chevrolet       gas        std          two
# 57          3               150      mazda       gas        std          two
# 55          3               150      mazda       gas        std          two
# 56          3               150      mazda       gas        std          two
# 32          1               101      honda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 18  hatchback          fwd           front        88.4  ...           61
# 57  hatchback          rwd           front        95.3  ...           70
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 32  hatchback          fwd           front        93.7  ...           79
#
# ...

# %%
df.sort_values(by=['symboling','engine-size'], ascending= [True, False])
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 194         -2               103          volvo       gas        std
# 196         -2               103          volvo       gas        std
# 198         -2               103          volvo       gas      turbo
# 71          -1                 ?  mercedes-benz       gas        std
# 67          -1                93  mercedes-benz    diesel      turbo
# ..         ...               ...            ...       ...        ...
# 190          3               256     volkswagen       gas        std
# 58           3               150          mazda       gas        std
# 55           3               150          mazda       gas        std
# 56           3               150          mazda       gas        std
# 57           3               150          mazda       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df.sort_values(by=['symboling','engine-size'], ascending= [True, False]).head()
# Out:
#      symboling normalized-losses           make fuel-type aspiration  \
# 194         -2               103          volvo       gas        std
# 196         -2               103          volvo       gas        std
# 198         -2               103          volvo       gas      turbo
# 71          -1                 ?  mercedes-benz       gas        std
# 67          -1                93  mercedes-benz    diesel      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 194         four      sedan          rwd           front       104.3  ...
# 196         four      sedan          rwd           front       104.3  ...
# 198         four      sedan          rwd           front       104.3  ...
# 71          four      sedan          rwd           front       115.6  ...
# 67          four      sedan          rwd           front       110.0  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
#replacing values in column
new = {'std':0, 'turbo':1}
df['aspiration']= df['aspiration'].map(new)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type  aspiration  \
# 0          3                 ?  alfa-romero       gas           0
# 1          3                 ?  alfa-romero       gas           0
# 2          1                 ?  alfa-romero       gas           0
# 3          2               164         audi       gas           0
# 4          2               164         audi       gas           0
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
old = {0:'std', 1:'turbo'}
df = df.replace({'aspiration':old})
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
#groupby
df.groupby(by='symboling')['engine-size'].describe()
# Out:
#            count        mean        std    min    25%    50%    75%    max
# symboling
# -2           3.0  137.333333   6.350853  130.0  135.5  141.0  141.0  141.0
# -1          22.0  146.363636  30.750216  110.0  122.0  141.0  168.5  234.0
#  0          67.0  134.671642  49.493308   90.0  108.0  120.0  152.0  326.0
#  1          54.0  109.444444  36.430687   79.0   91.0   97.0  110.0  304.0
#  2          32.0  113.656250  21.635707   61.0   97.0  109.0  133.0  146.0
#  3          27.0  141.259259  42.496690   70.0  115.5  151.0  171.0  234.0

# %%
#contingency table : relating two variables
pd.crosstab(df['aspiration'], df['symboling'], normalize = True)
# Out:
# symboling         -2        -1         0         1         2         3
# aspiration
# std         0.009756  0.068293  0.273171  0.229268  0.146341  0.092683
# turbo       0.004878  0.039024  0.053659  0.034146  0.009756  0.039024
